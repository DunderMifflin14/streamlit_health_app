# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import streamlit as st

# %%
def graph(df):

    fig, ax = plt.subplots()
    y = df.geo
    x = df.OBS_VALUE

    countries = df.geo.unique()
    num_countries = len(countries)

    y_axis = np.arange(num_countries)

    first_causes = df.loc[df.top_no == '1']
    second_causes = df.loc[df.top_no == '2']
    third_causes = df.loc[df.top_no == '3']
    bar_height = 0.3

    ax.barh(y_axis + bar_height, first_causes.OBS_VALUE, height = bar_height)
    ax.barh(y_axis, second_causes.OBS_VALUE, height = bar_height)
    ax.barh(y_axis-bar_height, third_causes.OBS_VALUE, height = bar_height)

    # Add labels to the bars using plt.text
    for i in range(len(countries)):
        ax.text(first_causes.OBS_VALUE.iloc[i] + 1, i + bar_height, first_causes.icd10.iloc[i], va='center', fontsize=14, style = 'italic')
        ax.text(second_causes.OBS_VALUE.iloc[i] + 1, i, second_causes.icd10.iloc[i], va='center', fontsize=14, style = 'italic')
        ax.text(third_causes.OBS_VALUE.iloc[i] + 1, i - bar_height, third_causes.icd10.iloc[i], va='center', fontsize=14, style = 'italic')

    ax.yticks(y_axis, countries, fontsize=16)
    ax.barh(x, y, 0.5)

    ax.yticks(y_axis, countries, fontsize=16)
    ax.title("Causes of death per EU country", fontsize=30)
    ax.legend()
    ax.show()


df = pd.read_csv("/Users/marta/Documents_/Andrew_project/streamlit_health_app/df_final.csv")
graph = graph(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 37
#      33     ax.show()
#      36 df = pd.read_csv("/Users/marta/Documents_/Andrew_project/streamlit_health_app/df_final.csv")
# ---> 37 graph = graph(df)
#
# Cell In[11], line 17, in graph(df)
#      14 third_causes = df.loc[df.top_no == '3']
#      15 bar_height = 0.3
# ---> 17 ax.barh(y_axis + bar_height, first_causes.OBS_VALUE, height = bar_height)
#      18 ax.barh(y_axis, second_causes.OBS_VALUE, height = bar_height)
#      19 ax.barh(y_axis-bar_height, third_causes.OBS_VALUE, height = bar_height)
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2641, in Axes.barh(self, y, width, height, left, align, data, **kwargs)
#    2531 r"""
#    2532 Make a horizontal bar plot.
#    2533
#    (...)
#    2638 :doc:`/gallery/lines_bars_and_markers/horizontal_barchart_distribution`.
#    2639 """
#    2640 kwargs.setdefault('orientation', 'horizontal')
# -> 2641 patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2642                    align=align, data=data, **kwargs)
#    2643 return patches
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2409, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2406     if yerr is not None:
#    2407         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2409 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2410     # Make args iterable too.
#    2411     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2413 # Now that units have been converted, set the tick locations.
#    2414 if orientation == 'vertical':
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/numpy/lib/stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 2 with shape (0,) and arg 3 with shape (32,).

# %%
df
y = df.OBS_VALUE
x = df.icd10

fig, ax = plt.subplots()
ax.barh(x,y)

plt.show(ax)
st.pyplot(ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 9
#       6 ax.barh(x,y)
#       8 plt.show(ax)
# ----> 9 st.pyplot(ax)
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/streamlit/runtime/metrics_util.py:396, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     394         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     395 try:
# --> 396     result = non_optional_func(*args, **kwargs)
#     397 except RerunException as ex:
#     398     # Duplicated from below, because static analysis tools get confused
#     399     # by deferring the rethrow.
#     400     if tracking_activated and command_telemetry:
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/streamlit/elements/pyplot.py:109, in PyplotMixin.pyplot(self, fig, clear_figure, use_container_width, **kwargs)
#     106     self.dg.exception(PyplotGlobalUseWarning())
#     108 image_list_proto = ImageListProto()
# --> 109 marshall(
#     110     self.dg._get_delta_path_str(),
#     111     image_list_proto,
#     112     fig,
#     113     clear_figure,
#     114     use_container_width,
#     115     **kwargs,
#     116 )
#     117 return self.dg._enqueue("imgs", image_list_proto)
#
# File ~/miniconda3/envs/health/lib/python3.11/site-packages/streamlit/elements/pyplot.py:161, in marshall(coordinates, image_list_proto, fig, clear_figure, use_container_width, **kwargs)
#     158 kwargs.update(options)
#     160 image = io.BytesIO()
# --> 161 fig.savefig(image, **kwargs)
#     162 image_width = (
#     163     image_utils.WidthBehaviour.COLUMN
#     164     if use_container_width
#     165     else image_utils.WidthBehaviour.ORIGINAL
#     166 )
#     167 image_utils.marshall_images(
#     168     coordinates=coordinates,
#     169     image=image,
#    (...)
#     175     output_format="PNG",
#     176 )
#
# AttributeError: 'Axes' object has no attribute 'savefig'
